# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
h_data = pd.read_csv('/content/drive/MyDrive/Heart_disease/heart.csv')

# %%
h_data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
h_data.shape
# Out:
# (303, 14)

# %%
h_data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
h_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
h_data.corr().style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_7c603_row0_col0, #T_7c603_row1_col1, #T_7c603_row2_col2, #T_7c603_row3_col3, #T_7c603_row4_col4, #T_7c603_row5_col5, #T_7c603_row6_col6, #T_7c603_row7_col7, #T_7c603_row8_col8, #T_7c603_row9_col9, #T_7c603_row10_col10, #T_7c603_row11_col11, #T_7c603_row12_col12, #T_7c603_row13_col13 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_7c603_row0_col1 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_7c603_row0_col2, #T_7c603_row4_col3, #T_7c603_row5_col12 {
#   background-color: #caddf0;
#   color: #000000;
# }
# #T_7c603_row0_col3, #T_7c603_row5_col9, #T_7c603_row10_col2, #T_7c603_row11_col12 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_7c603_row0_col4 {
#   background-color: #a9cfe5;
#   color: #000000;
# }
# #T_7c603_row0_col5 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_7c603_row0_col6, #T_7c603_row2_col8 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_7c603_row0_col7, #T_7c603_row1_col4, #T_7c603_row4_col6, #T_7c603_row6_col5, #T_7c603_row7_col0, #T_7c603_row8_col2, #T_7c603_row8_col13, #T_7c603_row9_col10, #T_7c603_row10_col9, #T_7c603_row13_col1, #T_7c603_row13_col3, #T_7c603_row13_col8, #T_7c603_row13_col11, #T_7c603_row13_col12 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_7c603_row0_col8, #T_7c603_row5_col0 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_7c603_row0_col9, #T_7c603_row2_col7, #T_7c603_row12_col9 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_7c603_row0_col10 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_7c603_row0_col11 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_7c603_row0_col12 {
#   background-color: #b4d3e9;
#   color: #000000;
# }
# #T_7c603_row0_col13, #T_7c603_row7_col9 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_7c603_row1_col0, #T_7c603_row10_col6 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_7c603_row1_col2, #T_7c603_row6_col12, #T_7c603_row12_col4 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_7c603_row1_col3 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_7c603_row1_col5, #T_7c603_row12_col6 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_7c603_row1_col6, #T_7c603_row9_col6 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_7c603_row1_col7, #T_7c603_row3_col7, #T_7c603_row13_col6 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_7c603_row1_col8 {
#   background-color: #92c4de;
#   color: #000000;
# }
# #T_7c603_row1_col9 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_7c603_row1_col10 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_7c603_row1_col11, #T_7c603_row4_col10, #T_7c603_row8_col11 {
#   background-color: #a1cbe2;
#   color: #000000;
# }
# #T_7c603_row1_col12, #T_7c603_row9_col12 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_7c603_row1_col13 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_7c603_row2_col0 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_7c603_row2_col1, #T_7c603_row12_col3 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_7c603_row2_col3, #T_7c603_row2_col6, #T_7c603_row7_col6 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_7c603_row2_col4, #T_7c603_row8_col5 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_7c603_row2_col5, #T_7c603_row10_col0, #T_7c603_row12_col2 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_7c603_row2_col9 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_7c603_row2_col10, #T_7c603_row9_col11 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_7c603_row2_col11 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_7c603_row2_col12 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_7c603_row2_col13 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_7c603_row3_col0 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_7c603_row3_col1, #T_7c603_row6_col1, #T_7c603_row9_col2 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_7c603_row3_col2, #T_7c603_row6_col7 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_7c603_row3_col4 {
#   background-color: #c1d9ed;
#   color: #000000;
# }
# #T_7c603_row3_col5 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_7c603_row3_col6, #T_7c603_row11_col13 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_7c603_row3_col8, #T_7c603_row4_col8, #T_7c603_row5_col2 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_7c603_row3_col9 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_7c603_row3_col10 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_7c603_row3_col11, #T_7c603_row8_col0 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_7c603_row3_col12 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_7c603_row3_col13, #T_7c603_row6_col0, #T_7c603_row8_col10 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_7c603_row4_col0 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_7c603_row4_col1, #T_7c603_row12_col13 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_7c603_row4_col2, #T_7c603_row6_col11 {
#   background-color: #cadef0;
#   color: #000000;
# }
# #T_7c603_row4_col5, #T_7c603_row13_col9 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_7c603_row4_col7, #T_7c603_row5_col7 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_7c603_row4_col9, #T_7c603_row6_col13 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_7c603_row4_col11, #T_7c603_row12_col0 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_7c603_row4_col12, #T_7c603_row5_col10, #T_7c603_row6_col9, #T_7c603_row8_col1 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_7c603_row4_col13 {
#   background-color: #c7dcef;
#   color: #000000;
# }
# #T_7c603_row5_col1, #T_7c603_row6_col8 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_7c603_row5_col3, #T_7c603_row5_col13 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_7c603_row5_col4, #T_7c603_row10_col12 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_7c603_row5_col6 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_7c603_row5_col8 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_7c603_row5_col11 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_7c603_row6_col2, #T_7c603_row11_col10 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_7c603_row6_col3 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_7c603_row6_col4, #T_7c603_row7_col8 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_7c603_row6_col10 {
#   background-color: #8abfdd;
#   color: #000000;
# }
# #T_7c603_row7_col1, #T_7c603_row7_col12, #T_7c603_row8_col3 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_7c603_row7_col2 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_7c603_row7_col3, #T_7c603_row9_col5 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_7c603_row7_col4 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_7c603_row7_col5, #T_7c603_row8_col6, #T_7c603_row11_col6 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_7c603_row7_col10 {
#   background-color: #4695c8;
#   color: #f1f1f1;
# }
# #T_7c603_row7_col11 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_7c603_row7_col13, #T_7c603_row13_col2 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_7c603_row8_col4 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_7c603_row8_col7 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_7c603_row8_col9 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_7c603_row8_col12 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_7c603_row9_col0 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_7c603_row9_col1, #T_7c603_row9_col3 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_7c603_row9_col4 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_7c603_row9_col7 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_7c603_row9_col8, #T_7c603_row11_col9 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_7c603_row9_col13 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_7c603_row10_col1 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_7c603_row10_col3, #T_7c603_row10_col5 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_7c603_row10_col4 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_7c603_row10_col7 {
#   backgrou

# %%
h_data['target'].value_counts()
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64

# %% [markdown]
# Splitting Target and Feature

# %%
X = h_data.drop(['target'], axis = 1)
Y = h_data['target']

# %%
print(X)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal
# 0        0   0     1
# 1        0   0     2
# 2        2   0     2
# 3        2   0     2
# 4        2   0     2
# ..     ...  ..   ...
# 298      1   0     3
# 299      1   0     3
# 300      1   2     3
# 301      1   1     3
# 302      1   1     2
#
# [303 rows x 13 columns]

# %%
print(Y)
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 298    0
# 299    0
# 300    0
# 301    0
# 302    0
# Name: target, Length: 303, dtype: int64

# %% [markdown]
# Splitting data into Training Data and Testing Data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.1, random_state=10)

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# USING SVM

# %%
from sklearn import svm

# %%
model = svm.SVC(kernel='linear')

# %%
# training the SVM model with training data
model.fit(X_train, Y_train)
# Out:
# SVC(kernel='linear')

# %%
# accuracy score on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(Y_train, X_train_prediction)

# %%
print('Accuracy score of training data : ', training_data_accuracy)
# Out:
# Accuracy score of training data :  0.8713235294117647

# %%
import pickle

# %%
filename='heart_svm'
pickle.dump(model,open(filename,'wb'))

# %% [markdown]
# USING LOGISTIC  REGRESSION
